# %% [markdown]
# # SmartSpend — Item-Level Expense Categorisation Model
#
# This notebook trains and evaluates the SmartSpend expense categorisation model using the new item-level dataset:
#
# `smartspend_initial_expense_category_classification_demo_dataset.csv`
#
# The model no longer learns from SMS `description` text only. It learns from the same fields the backend will have after receipt OCR or user clarification:
#
# - `item_name`
# - `normalized_item_name`
# - `merchant_name`
# - `to_who`
# - `quantity`
# - `unit`
# - `unit_cost_rwf`
# - `total_cost_rwf`
# - `purchase_month`
# - `purchase_weekday`
#
# Target label: `category`
#
# Training metadata columns such as `label_source` and `training_weight` are kept in the dataset, but are not prediction features. `training_weight` is used only as sample weight during training/retraining.

# %%
# %pip install joblib numpy pandas matplotlib scikit-learn

# %%
import json
import os

import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 140)

# %%
# Paths — dataset lives in backend_api/data/; model saves to backend_api/storage/models/
CATEGORY_DATASET = os.path.join(
    "..", "backend_api", "data",
    "smartspend_initial_expense_category_classification_demo_dataset.csv"
)
MODEL_OUT_DIR = os.path.join("..", "backend_api", "storage", "models")
os.makedirs(MODEL_OUT_DIR, exist_ok=True)

print("Dataset    :", CATEGORY_DATASET)
print("Model dir  :", MODEL_OUT_DIR)
# Out:
# Dataset    : ..\backend_api\data\smartspend_initial_expense_category_classification_demo_dataset.csv
# Model dir  : ..\backend_api\storage\models

# %% [markdown]
# ## 1. Load Dataset

# %%
category_df = pd.read_csv(CATEGORY_DATASET)
print("Shape   :", category_df.shape)
print("Columns :", list(category_df.columns))
display(category_df.head())
# Out:
# Shape   : (126, 13)
# Columns : ['item_name', 'normalized_item_name', 'merchant_name', 'to_who', 'quantity', 'unit', 'unit_cost_rwf', 'total_cost_rwf', 'purchase_month', 'purchase_weekday', 'category', 'label_source', 'training_weight']
#                  item_name normalized_item_name          merchant_name                 to_who  quantity unit  unit_cost_rwf  \
# 0         Hoima Sugar 50kg                sugar        Muteso Shop Ltd        Muteso Shop Ltd         1  bag          60100
# 1         Kabuye Sugar 1kg                sugar      Simba Supermarket      Simba Supermarket         2   kg           1800
# 2        Nyungwe Rice 25kg                 rice          Frulep Market          Frulep Market         1  bag          28000
# 3         Basmati Rice 5kg                 rice  Sawa Citi Supermarket  Sawa Citi Supermarket         1  bag           9500
# 4  Kawunga Maize Flour 5kg          maize flour    Mugisha Mini Market    Mugisha Mini Market         1  bag           6500
#
#    total_cost_rwf  purchase_month purchase_weekday   category label_source  training_weight
# 0           60100               6          Tuesday  Groceries    base_seed              1.0
# 1            3600               7         Saturday  Groceries    base_seed              1.0
# 2           28000               1           Monday  Groceries    base_seed              1.0
# 3            9500               9           Monday  Groceries    base_seed              1.0
# 4            6500               6           Friday  Groceries    base_seed              1.0

# %% [markdown]
# ## 2. Data Quality Checks

# %%
EXPECTED_COLUMNS = [
    "item_name",
    "normalized_item_name",
    "merchant_name",
    "to_who",
    "quantity",
    "unit",
    "unit_cost_rwf",
    "total_cost_rwf",
    "purchase_month",
    "purchase_weekday",
    "category",
    "label_source",
    "training_weight",
]

missing_columns = [c for c in EXPECTED_COLUMNS if c not in category_df.columns]
extra_columns = [c for c in category_df.columns if c not in EXPECTED_COLUMNS]

print("Missing expected columns:", missing_columns)
print("Extra columns:", extra_columns)
if missing_columns:
    raise ValueError(f"Dataset is missing required columns: {missing_columns}")

print("\nMissing values:")
display(category_df[EXPECTED_COLUMNS].isna().sum().to_frame("missing_count"))

print("\nDuplicate rows:", category_df.duplicated().sum())

print("\nCategory distribution:")
display(category_df["category"].value_counts().to_frame("count"))

print("\nLabel source distribution:")
display(category_df["label_source"].value_counts().to_frame("count"))

print("\nTraining weight summary:")
display(category_df["training_weight"].describe().to_frame("training_weight"))
# Out:
# Missing expected columns: []
# Extra columns: []
#
# Missing values:
#                       missing_count
# item_name                         0
# normalized_item_name              0
# merchant_name                     0
# to_who                            0
# quantity                          0
# unit                              0
# unit_cost_rwf                     0
# total_cost_rwf                    0
# purchase_month                    0
# purchase_weekday                  0
# category                          0
# label_source                      0
# training_weight                   0
# Duplicate rows: 0
#
# Category distribution:
#                     count
# category
# Groceries              30
# Household              10
# Transport              10
# Electronics            10
# Personal Care           8
# Healthcare              8
# Education               8
# Clothing                8
# Home Improvement        6
# Utilities               5
# Telecom                 5
# Dining                  5
# Entertainment           4
# Financial Services      3
# Housing                 2
# Gifts & Donations       2
# Health & Fitness        1
# Donations               1
# Label source distribution:
#               count
# label_source
# base_seed       126
# Training weight summary:
#        training_weight
# count            126.0
# mean               1.0
# std                0.0
# min                1.0
# 25%                1.0
# 50%                1.0
# 75%                1.0
# max                1.0

# %% [markdown]
# ## 3. Data Engineering
#
# The backend should pass the same feature columns used here when predicting categories.
#
# `label_source` and `training_weight` are not model input features. `training_weight` is passed as `sample_weight` during fitting so that user corrections can carry more influence during retraining.

# %%
df = category_df.copy()

TEXT_SOURCE_COLUMNS = ["item_name", "normalized_item_name", "merchant_name", "to_who", "unit"]
NUMERIC_FEATURE_COLUMNS = ["quantity", "unit_cost_rwf", "total_cost_rwf", "purchase_month", "purchase_weekday"]
FEATURE_COLUMNS = ["model_text"] + NUMERIC_FEATURE_COLUMNS
TARGET_COLUMN = "category"
WEIGHT_COLUMN = "training_weight"

for col in TEXT_SOURCE_COLUMNS:
    df[col] = df[col].fillna("").astype(str).str.strip()

for col in NUMERIC_FEATURE_COLUMNS + [WEIGHT_COLUMN]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Make a single text field from all text/categorical context.
# This keeps serving simple while still using item, merchant/provider, to_who, and unit signals.
df["model_text"] = (
    "item: " + df["item_name"] +
    " | normalized: " + df["normalized_item_name"] +
    " | merchant: " + df["merchant_name"] +
    " | to_who: " + df["to_who"] +
    " | unit: " + df["unit"]
)

df["text_length"] = df["model_text"].str.len()
df["word_count"] = df["model_text"].str.split().str.len()

model_df = df[FEATURE_COLUMNS + [TARGET_COLUMN, WEIGHT_COLUMN, "label_source"]].dropna(subset=[TARGET_COLUMN]).copy()
model_df[WEIGHT_COLUMN] = model_df[WEIGHT_COLUMN].fillna(1.0)

print("Training rows:", len(model_df))
print("Feature columns:", FEATURE_COLUMNS)
print("Target column:", TARGET_COLUMN)
display(model_df.head(10))
# Out:
# Training rows: 126
# Feature columns: ['model_text', 'quantity', 'unit_cost_rwf', 'total_cost_rwf', 'purchase_month', 'purchase_weekday']
# Target column: category
#                                           model_text  quantity  unit_cost_rwf  total_cost_rwf  purchase_month  purchase_weekday  \
# 0  item: Hoima Sugar 50kg | normalized: sugar | m...         1          60100           60100               6               NaN
# 1  item: Kabuye Sugar 1kg | normalized: sugar | m...         2           1800            3600               7               NaN
# 2  item: Nyungwe Rice 25kg | normalized: rice | m...         1          28000           28000               1               NaN
# 3  item: Basmati Rice 5kg | normalized: rice | me...         1           9500            9500               9               NaN
# 4  item: Kawunga Maize Flour 5kg | normalized: ma...         1           6500            6500               6               NaN
# 5  item: Amandazi Flour 2kg | normalized: wheat f...         1           3000            3000               1               NaN
# 6  item: Sunseed Cooking Oil 5L | normalized: coo...         1          12500           12500               4               NaN
# 7  item: Akabanga Chili Oil 20ml | normalized: ch...         2           1200            2400               2               NaN
# 8  item: Inyange Milk 1L | normalized: milk | mer...         3           1200            3600               7               NaN
# 9  item: Nyanza Dairy Yogurt 500ml | normalized: ...         2           1500            3000               4               NaN
#
#     category  training_weight label_source
# 0  Groceries              1.0    base_seed
# 1  Groceries              1.0    base_seed
# 2  Groceries              1.0    base_seed
# 3  Groceries              1.0    base_seed
# 4  Groceries              1.0    base_seed
# 5  Groceries              1.0    base_seed
# 6  Groceries              1.0    base_seed
# 7  Groceries              1.0    base_seed
# 8  Groceries              1.0    base_seed
# 9  Groceries              1.0    base_seed

# %% [markdown]
# ## 4. Visualisations

# %%
# 4.1 Category distribution / 4.2 Label source distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

cat_counts = model_df["category"].value_counts().sort_values(ascending=False)
cat_counts.plot(kind="bar", ax=axes[0])
axes[0].set_title("Expense Category Distribution")
axes[0].set_xlabel("Category")
axes[0].set_ylabel("Count")
axes[0].tick_params(axis="x", rotation=45)

model_df["label_source"].value_counts().plot(kind="bar", ax=axes[1])
axes[1].set_title("Label Source Distribution")
axes[1].set_xlabel("Label Source")
axes[1].set_ylabel("Count")
axes[1].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

cat_pct = (cat_counts / cat_counts.sum() * 100).round(2)
display(cat_pct.to_frame("percentage_of_training_set"))
# Out:
#                     percentage_of_training_set
# category
# Groceries                                23.81
# Household                                 7.94
# Transport                                 7.94
# Electronics                               7.94
# Personal Care                             6.35
# Healthcare                                6.35
# Education                                 6.35
# Clothing                                  6.35
# Home Improvement                          4.76
# Utilities                                 3.97
# Telecom                                   3.97
# Dining                                    3.97
# Entertainment                             3.17
# Financial Services                        2.38
# Housing                                   1.59
# Gifts & Donations                         1.59
# Health & Fitness                          0.79
# Donations                                 0.79

# %%
# 4.3 Amount distributions
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

model_df["total_cost_rwf"].plot(kind="hist", bins=30, ax=axes[0])
axes[0].set_title("Total Cost Distribution")
axes[0].set_xlabel("Total Cost (RWF)")
axes[0].set_ylabel("Frequency")

model_df.boxplot(column="total_cost_rwf", by="category", ax=axes[1], rot=45)
axes[1].set_title("Total Cost by Category")
axes[1].set_xlabel("")
axes[1].set_ylabel("Total Cost (RWF)")
fig.suptitle("")

model_df.groupby("category")["total_cost_rwf"].mean() \
    .sort_values(ascending=False).plot(kind="bar", ax=axes[2])
axes[2].set_title("Average Total Cost by Category")
axes[2].set_xlabel("")
axes[2].set_ylabel("Average Total Cost (RWF)")
axes[2].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %%
# 4.4 Text length and word count
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

model_df["model_text"].str.len().plot(kind="hist", bins=30, ax=axes[0, 0])
axes[0, 0].set_title("Model Text Length Distribution")
axes[0, 0].set_xlabel("Character Count")

model_df["model_text"].str.split().str.len().plot(kind="hist", bins=20, ax=axes[0, 1])
axes[0, 1].set_title("Model Text Word Count Distribution")
axes[0, 1].set_xlabel("Word Count")

model_df.assign(word_count=model_df["model_text"].str.split().str.len()).boxplot(
    column="word_count", by="category", ax=axes[1, 0], rot=45
)
axes[1, 0].set_title("Word Count by Category")
axes[1, 0].set_xlabel("")
fig.suptitle("")

model_df.assign(text_length=model_df["model_text"].str.len()).groupby("category")["text_length"].mean() \
    .sort_values(ascending=False).plot(kind="bar", ax=axes[1, 1])
axes[1, 1].set_title("Average Model Text Length by Category")
axes[1, 1].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Model Architecture
#
# The categorisation model is a scikit-learn `Pipeline` with:
#
# | Step | Component | Purpose |
# |---|---|---|
# | Text features | `TfidfVectorizer` | Learns from item, normalized item, merchant/provider, `to_who`, and unit text |
# | Numeric features | `SimpleImputer` + `StandardScaler` | Learns from quantity, unit cost, total cost, purchase month, and purchase weekday |
# | Classifier | `LogisticRegression` | Predicts the expense category |
#
# This structure remains retraining-friendly: the backend can rebuild the same feature frame from seed rows, user prompt rows, confirmed receipt rows, and user corrections.

# %% [markdown]
# ## 6. Train and Evaluate

# %%
text_features = "model_text"
numeric_features = NUMERIC_FEATURE_COLUMNS

preprocess = ColumnTransformer(
    transformers=[
        ("text", TfidfVectorizer(ngram_range=(1, 2), max_features=3000, min_df=1), text_features),
        ("num", Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", StandardScaler()),
        ]), numeric_features),
    ],
    remainder="drop",
)

pipeline = Pipeline([
    ("preprocess", preprocess),
    ("classifier", LogisticRegression(
        C=0.5, max_iter=1000, class_weight="balanced", random_state=42
    )),
])

X = model_df[FEATURE_COLUMNS]
y = model_df[TARGET_COLUMN]
sample_weight = model_df[WEIGHT_COLUMN].astype(float)

min_class_count = y.value_counts().min()
n_splits = min(5, int(min_class_count))

if n_splits >= 2:
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    cv_scores = cross_val_score(
        pipeline, X, y, cv=cv, scoring="accuracy", n_jobs=-1
    )
    print(f"{n_splits}-fold CV accuracy : {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
    print(f"Fold scores        : {[round(s, 4) for s in cv_scores]}")
else:
    cv_scores = np.array([])
    print("Cross-validation skipped: at least one category has fewer than 2 rows.")

X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(
    X, y, sample_weight,
    test_size=0.2,
    random_state=42,
    stratify=y if min_class_count >= 2 else None,
)

pipeline.fit(X_train, y_train, classifier__sample_weight=w_train)
y_pred = pipeline.predict(X_test)

cat_metrics = {
    "test_accuracy": float(accuracy_score(y_test, y_pred)),
    "test_precision_macro": float(precision_score(y_test, y_pred, average="macro", zero_division=0)),
    "test_recall_macro": float(recall_score(y_test, y_pred, average="macro", zero_division=0)),
    "test_f1_macro": float(f1_score(y_test, y_pred, average="macro", zero_division=0)),
    "test_f1_weighted": float(f1_score(y_test, y_pred, average="weighted", zero_division=0)),
    "cv_mean_accuracy": float(cv_scores.mean()) if len(cv_scores) else None,
    "cv_std_accuracy": float(cv_scores.std()) if len(cv_scores) else None,
    "feature_columns": FEATURE_COLUMNS,
    "target_column": TARGET_COLUMN,
    "uses_sample_weight": True,
}
print(json.dumps(cat_metrics, indent=2))
print("\nClassification report:")
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# Cross-validation skipped: at least one category has fewer than 2 rows.
# {
#   "test_accuracy": 0.23076923076923078,
#   "test_precision_macro": 0.3333333333333333,
#   "test_recall_macro": 0.27619047619047615,
#   "test_f1_macro": 0.2833333333333333,
#   "test_f1_weighted": 0.25961538461538464,
#   "cv_mean_accuracy": null,
#   "cv_std_accuracy": null,
#   "feature_columns": [
#     "model_text",
#     "quantity",
#     "unit_cost_rwf",
#     "total_cost_rwf",
#     "purchase_month",
#     "purchase_weekday"
#   ],
#   "target_column": "category",
#   "uses_sample_weight": true
# }
#
# Classification report:
#                   precision    recall  f1-score   support
#
#         Clothing       1.00      1.00      1.00         1
#           Dining       0.00      0.00      0.00         1
#        Donations       0.00      0.00      0.00         0
#        Education       0.00      0.00      0.00         1
#      Electronics       0.50      0.50      0.50         2
#    Entertainment       0.00      0.00      0.00         1
#        Groceries       1.00      0.14      0.25         7
#       Healthcare       0.00      0.00      0.00         3
# Home Improvement       1.00      1.00      1.00         1
#        Household       0.50      0.50      0.50         2
#          Housing       0.00      0.00      0.00         1
#    Personal Care       0.00      0.00      0.00         3
#          Telecom       1.00      1.00      1.00         1
#        Transport       0.00      0.00      0.00         1
#        Utilities       0.00      0.00      0.00         1
#
#         accuracy                           0.23        26
#        macro avg       0.33      0.28      0.28        26
#     weighted avg       0.46      0.23      0.26        26
# c:\Users\USER\Documents\smart-spend\ml\.venv\Lib\site-packages\sklearn\impute\_base.py:647: UserWarning: Skipping features without any observed values: ['purchase_weekday']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(
# c:\Users\USER\Documents\smart-spend\ml\.venv\Lib\site-packages\sklearn\impute\_base.py:647: UserWarning: Skipping features without any observed values: ['purchase_weekday']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(

# %%
# 6.3 Confusion matrices: raw + normalized
labels = sorted(model_df["category"].unique())
fig, axes = plt.subplots(1, 2, figsize=(22, 9))

cm = confusion_matrix(y_test, y_pred, labels=labels)
ConfusionMatrixDisplay(cm, display_labels=labels).plot(
    ax=axes[0], xticks_rotation=45, values_format="d"
)
axes[0].set_title("Confusion Matrix")

cm_norm = confusion_matrix(y_test, y_pred, labels=labels, normalize="true")
ConfusionMatrixDisplay(cm_norm, display_labels=labels).plot(
    ax=axes[1], xticks_rotation=45, values_format=".2f"
)
axes[1].set_title("Normalized Confusion Matrix")

plt.tight_layout()
plt.show()

# %%
# 6.4 Per-category F1 scores
report_dict = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
per_class_df = pd.DataFrame(
    [{**v, "category": k} for k, v in report_dict.items() if k in labels]
).set_index("category")
display(per_class_df[["precision", "recall", "f1-score", "support"]])

plt.figure(figsize=(12, 5))
per_class_df["f1-score"].sort_values().plot(kind="bar")
plt.title("F1 Score by Expense Category")
plt.xlabel("Category")
plt.ylabel("F1 Score")
plt.ylim(0, 1.05)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
#                   precision    recall  f1-score  support
# category
# Clothing                1.0  1.000000      1.00      1.0
# Dining                  0.0  0.000000      0.00      1.0
# Donations               0.0  0.000000      0.00      0.0
# Education               0.0  0.000000      0.00      1.0
# Electronics             0.5  0.500000      0.50      2.0
# Entertainment           0.0  0.000000      0.00      1.0
# Groceries               1.0  0.142857      0.25      7.0
# Healthcare              0.0  0.000000      0.00      3.0
# Home Improvement        1.0  1.000000      1.00      1.0
# Household               0.5  0.500000      0.50      2.0
# Housing                 0.0  0.000000      0.00      1.0
# Personal Care           0.0  0.000000      0.00      3.0
# Telecom                 1.0  1.000000      1.00      1.0
# Transport               0.0  0.000000      0.00      1.0
# Utilities               0.0  0.000000      0.00      1.0

# %%
# 6.5 Prediction confidence distribution
proba = pipeline.predict_proba(X_test)
confidence = proba.max(axis=1)

confidence_df = pd.DataFrame({
    "true_category": y_test.values,
    "predicted_category": y_pred,
    "confidence": confidence,
    "correct": y_test.values == y_pred,
})
display(confidence_df.head())

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

confidence_df["confidence"].plot(kind="hist", bins=30, ax=axes[0])
axes[0].set_title("Confidence Score Distribution")
axes[0].set_xlabel("Max Predicted Probability")
axes[0].set_ylabel("Frequency")

confidence_df.boxplot(column="confidence", by="correct", ax=axes[1])
axes[1].set_title("Confidence by Prediction Correctness")
axes[1].set_xlabel("Prediction Correct")
axes[1].set_ylabel("Confidence")
plt.suptitle("")

plt.tight_layout()
plt.show()
# Out:
# c:\Users\USER\Documents\smart-spend\ml\.venv\Lib\site-packages\sklearn\impute\_base.py:647: UserWarning: Skipping features without any observed values: ['purchase_weekday']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(
#       true_category predicted_category  confidence  correct
# 0     Entertainment             Dining    0.129875    False
# 1         Groceries          Education    0.319677    False
# 2  Home Improvement   Home Improvement    0.205934     True
# 3            Dining          Donations    0.170988    False
# 4       Electronics        Electronics    0.573782     True

# %%
# 6.6 Top TF-IDF terms per category
text_step = pipeline.named_steps["preprocess"].named_transformers_["text"]
clf_step = pipeline.named_steps["classifier"]
feature_names = np.array(text_step.get_feature_names_out())
text_coef_count = len(feature_names)

top_terms_rows = []
for class_idx, class_label in enumerate(clf_step.classes_):
    text_coefs = clf_step.coef_[class_idx][:text_coef_count]
    top_indices = np.argsort(text_coefs)[-10:][::-1]
    top_terms_rows.append({
        "category": class_label,
        "top_terms": ", ".join(feature_names[top_indices]),
    })

display(pd.DataFrame(top_terms_rows).set_index("category"))
# Out:
#                                                             top_terms
# category
# Clothing            kigali fashion, fashion, fashion shop, shop, s...
# Dining              meal, chez, brochette, lando, chez lando, pizz...
# Donations           church, offering, unit donation, merchant chur...
# Education           bookshop kigali, bookshop, uniform, school, to...
# Electronics         phone, phone house, computer, zone, zone rwand...
# Entertainment       ticket, netflix, cinema, amahoro, amahoro stad...
# Financial Services  bank, fee, bank of, of, of kigali, mobile mone...
# Gifts & Donations   gift, contribution, gift shop, wedding contrib...
# Groceries           market, supermarket, flour, market to_who, mar...
# Health & Fitness    membership, waka fitness, waka, gym, fitness, ...
# Healthcare          clinic, clinic rwanda, rwanda, test, optica rw...
# Home Improvement    hardware, hardware shop, shop kigali, shop, me...
# Household           supermarket, simba supermarket, simba, toilet,...
# Housing             rent, landlord, to_who landlord, rent merchant...
# Personal Care       pharmacy, pharmacy kigali, toothbrush, kigali,...
# Telecom             mtn, airtime, rwanda, mtn rwanda, internet, ai...
# Transport           taxi, ride, parking, yego, moto, car, car wash...
# Utilities           canalplus, subscription, dstv, bill, wasac, el...

# %% [markdown]
# ## 7. Save Model Artefacts
#
# The saved model is fitted on the full available dataset after evaluation. This is the artefact the backend should load for cold-start categorisation.
#
# During backend retraining, rebuild the same feature columns, include user correction rows, pass `training_weight` as sample weight, and save a user-specific model.

# %%
# Fit the production artefact on the full dataset.
final_pipeline = pipeline
final_pipeline.fit(X, y, classifier__sample_weight=sample_weight)

model_path = os.path.join(MODEL_OUT_DIR, "smartspend_category_model.joblib")
joblib.dump(final_pipeline, model_path)
print("Model saved   :", model_path)

metadata = {
    "dataset": CATEGORY_DATASET,
    "feature_columns": FEATURE_COLUMNS,
    "text_source_columns": TEXT_SOURCE_COLUMNS,
    "numeric_feature_columns": NUMERIC_FEATURE_COLUMNS,
    "target_column": TARGET_COLUMN,
    "weight_column": WEIGHT_COLUMN,
    "prediction_contract": {
        "required_input_columns": [
            "item_name", "normalized_item_name", "merchant_name", "to_who",
            "quantity", "unit", "unit_cost_rwf", "total_cost_rwf",
            "purchase_month", "purchase_weekday"
        ],
        "build_model_text_as": "item + normalized_item + merchant_name + to_who + unit",
        "amount_currency": "RWF"
    },
    "metrics": cat_metrics,
}

metrics_path = os.path.join(MODEL_OUT_DIR, "categorisation_metrics.json")
with open(metrics_path, "w") as f:
    json.dump(metadata, f, indent=2)
print("Metrics saved :", metrics_path)
# Out:
# Model saved   : ..\backend_api\storage\models\smartspend_category_model.joblib
# Metrics saved : ..\backend_api\storage\models\categorisation_metrics.json
# c:\Users\USER\Documents\smart-spend\ml\.venv\Lib\site-packages\sklearn\impute\_base.py:647: UserWarning: Skipping features without any observed values: ['purchase_weekday']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(
